# %% [markdown]
# <a href="https://colab.research.google.com/github/amitdhanoriyacode30-gif/Python-/blob/main/listortuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list comrehension

#data  = [ i *1 for ]
# lis = [1,2,3,4,True,"hello"]

 if "3" in lis:
     print("yes")
 else:
     print("no")

 data = [i*i for i in range(5) if i%2==0]
 print(data)

 empty = []
 for i in range(5):
     empty.append(i)
print("output:",empty)

12/06
#list method

 lis = [1,2,3,4,11]
 lis.clear

 lis.append(80)
#
 print(lis)

print(lis.count(3))

print(lis.index)


lis.insert(2,49)

lis.remove(3)

lis.pop(5)

lis.sort()

print("output",lis)

# %%
#tuple are odered
# tuple are immutble
#Tuple can use to store multiple value

tup = (1,3,4,3,6,7)

tup[1] = 10

print(type(tup))

tup = [1]
print(type(tup))


tup = (1,2,3,4,5)
print(tup[2:5])

print(tup.count(3))

print(tup.index(3,2,5))

tup = (2,3,4,5,)
lis = list(tup)
lis.append(90)
lis.pop(2)
lis.insert(3,10)
tup = tuple(lis)
print(tup)

#tuple are odered
# tuple are immutble
#Tuple can use to store multiple value

tup = (1,3,4,3,6,7)

tup[1] = 10

print(type(tup))

tup = [1]
print(type(tup))


tup = (1,2,3,4,5)
print(tup[2:5])

print(tup.count(3))

print(tup.index(3,2,5))

tup = (2,3,4,5,)
lis = list(tup)
lis.append(90)
lis.pop(2)
lis.insert(3,10)
tup = tuple(lis)
print(tup)

# %%
#Set  are unorder
#Set are immutable
# Set removes duplicate values

s1 = {'helo',1,2,5,4,3,}
s2 = {1}
#find the union in the set
print(s1.union(s2))

#Find the intersection in the set
print(s1.intersection(s2))

# s1.intersection_update(s2)

print(s1.difference(s2))

print(s2.difference(s1))

print(s1.symmetric_difference(s2))

print(s1.issubset(s2))

print(s2.issubset(s1))

#adding value in the set

s = {1,3,6,7,5,4}
#add the value in the set
s.add(80)
#remove the element from the set
s.remove(1)
# remove the rendam elment from the set
s.pop()
print(s)
