# %% [markdown]
# <a href="https://colab.research.google.com/github/amitdhanoriyacode30-gif/Python-/blob/main/labsclg_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#11/05/2026
# write the program of addition to use of match method
def calculator():
    print("Simple calculator")
    print("1. additon")
    print("2. subration")
    print("3. multiplication")
    print("4. divion")

    choice = int(input("enter the value"))
    a = float(input("enter the first value:"))
    b = float(input("enter the second value:-"))

    match choice:
        case 1:
            print("result =",a+b)
        case 2:
            print("result = ",a-b)
        case 3:
            print("result = ", a*b)
        case 4:

            if(b!=0):
                print("reslut = ",a/b)
            else:
                print("divion bt zero is no allowed")

#star petterns

for i in range(1,5):
    print("*"*i)
for j in range(1,5):
    print("*"*j)


for k in range(1,6,-1):
    print("*"*k)


 #while loop
 #while loop

 #while loop
i = 10
while(i<1):
    print(i)
    i = i+1

#wrote a program that keep
num = int(input("enter the password:"))
while(num!=40):
    num = int(input("enter the password:"))

# print("Passowrd correct")

write the code of reverrse number
i = int(input("enter the one number:-"))
while(i>=1):
    print(i)
    i = i-1

# break statement - (Break staten=ment are used to stop the loop without compliting)
the condition
for i in range(1,11):
    if(i%2==0):
        break
        print(i)

#continue statement - ( continue statement are skip th particuler iteration and)
forword the loop by on stop
for i in range(1,11):
    if(i%2==0):
        continue
    print(i)

#pass
for i in range(1,11):
    if(i%2==0):
        pass
    print(i)

# %%
#08.05 = assiment for python
#write a program that asks the user for a number and points whether is is positive nagative or zero

num1 = float(input("enter the number:-"))
if(num1>=0):
    print("the number is positve")
elif(num1<0):
    print("the number is negative")
elif(num1==0):
    print("the number is zero")

# write a  create  TO THAT CHECK if a person is eligible to vote (age>=18) or not

age = int(input("Please enter your your age:- "))

if(age>=18):
    print("your  eligible for vote")
else:
    print("sorry your not elgible for vote")

#calculate the sum of all number from 1to 100 using a for loop

a = 0
for i in range(1,101):
    a += i
    print("Sum=",a)

#write a program that take a number from the user an print "even"if it is even otherwise odd
num = int(input("enter the value:_"))
if(num%2==0):
    print("the number is even_",num)
else:
    print("the number is the odd:-",num).

#for loop

#print number from 1 to 100 using a loop
for i in range(1,101):
    print("the num is ",i)


#Write the multiplication table of a number(entered by the user)
a = int(input("enter the  number:_"))
for i in range(1,11):

    print(a,"X",i,"=",(a*i))
# Out:
# enter the number:-2
# the number is positve

# %%
#04/05
#use of while loops
#write the program to check a given number is prime or not
 #while loop
i = 5
while(i>=1):
    print(i)
    i = i-1

 #write the program  to terinate an infinite loop

num = int(input("enter the number :-"))
while(num<=40):
    num = int(input("enter the number :"))
    print("num")
print("loop stop")

#write a prgram to reverse a number 123 = 321

n = 123
p = n
sum = 0
while(n>0):
    r = n%10 #3 2 1
    sum = sum*10+r #3 32 321
    n = n//10 #12 1 0
if(sum==p):
    print("this number is  palindrome")
else:
    print("this number is not palindrome")

 #writw a program to the print the sum of indvidual if a givrn number

n = 123
sum = 0
while(n>0):
    r = n%10
    sum = sum+r
    n = n//10
print(sum)

 #write a program to check a given number is armstrongs or not
 #153 = 1+125+27=153, 370 = 27 + 343 +0 = 370 , 125 = 1+8+125
n = int(input("enter the number :-"))

# %%
#01/05/26
#write a program  to print the sum of n numbers using  for loop
sum = 0
n = int(input("enter the number :"))
for i in range(1,n+1):
    sum = sum + i
    print(sum)

#write a  program to print the factorial of a given number
sum = 1
n = int(input("enter the number"))
for i in range(1,n+1):
    sum = sum*i
    print(i,sum)

#write a  program to print the factors of given numbers
fact = 1
b = int(input("enter the number : "))
for i in range (1,b+1):
    if(b%i==0):
        print("the given factors is :",i)

#write a program to check a given number is perfact or not
n = int(input("enter the number :"))
sum = 0
for i in range(1,n):
    if(n%i==0):
        sum = sum+i
print(sum)

n = int(input("enter the number :"))
sum = 0
for i in range(1,n):
    if(n%i==0):
        sum = sum+i
print(sum)
if(sum==n):
    print("number is perfact ")
else:
    print("the number is not perfact")

# %%
#30/04
#loop Statement - Loop Statement are used to repeat the certain statement
#again and again until the condition is true
#Types of Loop
#1.for, 2.while

#Syntax

for i in range(6):
  print(i)
print("today")

for j in range(6,1,-1):
  print(j)

name = "akask"
for i in name:
  print(i)

 # write a program to print the table of ANG GIVEN NUMBER
num = int(input("enter the number : "))
for a in range(1,11):
  print(num,"X",a,"=",a*num)

#Write a program to print even number between 1to 20
# Out:
# 6
# 5
# 4
# 3
# 2
# a
# k
# a
# s
# k
# enter the number : 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
#Write a program to print even number between 1to 20
n = int(input("enter the number"))
for l in range (1,n+1
                ):
  if(l%2==0):
    print("the number is even",l)
# Out:
# enter the number80
# the number is even 2
# the number is even 4
# the number is even 6
# the number is even 8
# the number is even 10
# the number is even 12
# the number is even 14
# the number is even 16
# the number is even 18
# the number is even 20
# the number is even 22
# the number is even 24
# the number is even 26
# the number is even 28
# the number is even 30
# the number is even 32
# the number is even 34
# the number is even 36
# the number is even 38
# the number is even 40
# the number is even 42
# the number is even 44
# the number is even 46
# the number is even 48
# the number is even 50
# the number is even 52
# the number is even 54
# the number is even 56
# the number is even 58
# the number is even 60
# the number is even 62
# the number is even 64
# the number is even 66
# the number is even 68
# the number is even 70
# the number is even 72
# the number is even 74
# the number is even 76
# the number is even 78
# the number is even 80

# %%
#conditional statement = Conditional Statement either gives reuslt true
# true   or false
# Types of conditional Statement
# if  esle statement
# nested if statement
# ladder if else statement

#if statement - it only gives true result
# indentation  used in python instead of blocks

age = int(input("enter your age"))
if(age >= 18):
    print("you are vote")
else:
    print("sorry you can not give vote")
# Out:
# enter your age16
# sorry you can not give vote

# %%
#write a program of odd or even
even = int(input("enter the value:"))
if(even%2 == 0):
  print("this value is even")
else:
  print("the given value is odd")

# write a program to check grater between two numbers
a = int(input("enter first value"))
b = int(input("enter the second value:"))
if(a<b):
  print("first value is grater")
else:
  print("the secon value is less")
# Out:
# enter the value:2
# this value is even
# enter first value1
# enter the second value:3
# first value is grater

# %%
# write a program to check grater between two numbers
a = int(input("enter first value:"))
b = int(input("enter the second value:"))
if(a<b):
  print("first value is grater")
else:
  print("the secon value is less")
# Out:
# enter first value:5

# %%
#writre a programs to check grater
a = int(input("enter first value:"))
b = int(input("enter the second value:"))
c = int(input("enter the third value:"))

if (a>b):
  if(a>c):
      print("the a is grater")
  else:
      if(b>c):
            print("the b is grater")
      else:
          print("the c is geater")
else:
    if(b>c):
           print("the b is grater")
    else:
         print("the c is grater")

# %%
#write a program to check a given year is leap year or not
year = int(input("enter the year"))
if(year%400==0):
  print(year,"is a leap year")
else:
  if(year%100!=0):
    print(year,"is a not leap year")
  else:
    if(year%4==0):
      print(year,"is leap year")
    else:
      print(year,"is not leap year")
# Out:
# enter the year2000
# 2000 is a leap year

# %%
#ladder a if else
#wirte a program  to check grater  between  three number
a = int(input("enter first value : "))
b = int(input("enter second value : "))
c = int(input("enter third value : "))

if(a>b and a>c):
  print("a is grater")
elif(b>c):
  print("b is grater")
else:
  print("c is grater")
# Out:
# enter first value : 2
# enter second value : 3
# enter third value : 5
# c is grater

# %%
# check the fourv no .
a = int(input("enter first value : "))
b = int(input("enter second value : "))
c = int(input("enter thirf value : "))
d = int(input("enter fourth value : "))
if(a>b and a>c):
  print("a is grater")
elif(b>c):
  print("b is grater")
elif(c>d):
  print("c is grater")
else:
  print("d is grater")
# Out:
# enter first value : 1
# enter second value : 2
# enter thirf value : 3
# enter fourth value : 4
# d is grater

# %%
#Write a program to check a number is +ve, -ve , or zero
a = int(input("enter first value : "))
if(a>0):
  print("the number is grater")
elif(a>0):
  print("the number is less than by :")
else:
  print("the number is zero")
# Out:
# enter first value : -6
# the number is zero

# %%
#wirte a program to check a given triangle is isoceles, equilateral or scalane
a = float(input("enter first value :"))
b = float(input("enter first value :"))
c = float(input("enter the third value :"))
if(a==b!=c):
  print("this is the equilateral triangle")
elif(a==b or b==c or c==a):
  print("this is the isoceles triangle ")
else:
  print("this is the scalane")
# Out:
# enter first value :1
# enter first value :1
# enter the third value :1
# this is the isoceles triangle

# %%
#Wirte the program (a+b,b>c,b+c>a,a+c)
a = int(input("enter first value : "))
b = int(input("enter second value : "))
c = int(input("enter third value : "))
if(a+b,b>c,b+c>a,a+c):
  print("the perfect triangle")
else:
  print("this is not perfect triangle")
# Out:
# enter first value : 2
# enter second value : 1
# enter third value : 3
# the perfect triangle
