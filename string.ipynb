# %% [markdown]
# <a href="https://colab.research.google.com/github/amitdhanoriyacode30-gif/Python-/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#String - when a value enclosed by single or  double quotatoin marks called string
#string is a textual data
#adding two or more string in python
name = "Lokesh"
friend = "choudry"

mango = """ Mango is sweet fruit
it has lots of variety"""
print(type(mango))
print(name,"is friend of ", friend, "and he likes",mango)
city = "indore"
print(city[0])
print(city[3])

for i in city:
  print(i)


#string slicing
city = "Indore"
print(city[0:3])
print(city[2:4])
print(city[-4:-1])
print(city[2:5])
print(len(city))
print(city[len(city)-4:len(city)-1])

# #that is not print beacuse that case is not possible
print(city[-2:-4])
print(city[5:2])

#string method

name = "Harmoon is form of haru"
#String is the immutable
name1 = name.lower()
print(name1)
# in that the first letter is the small
print(name.lower())
# in that the all leters are the capital
print(name.upper())
#in tha the only first letter is big and all is small ex - harmmin
print(name.capitalize())
# in that the only count the letter in sentance
print(name.count("i"))
# Out:
# <class 'str'>
# Lokesh is friend of  choudry and he likes  Mango is sweet fruit
# it has lots of variety
# i
# o
# i
# n
# d
# o
# r
# e
# Ind
# do
# dor
# dor
# 6
# dor
#
#
# harmoon is form of haru
# harmoon is form of haru
# HARMOON IS FORM OF HARU
# Harmoon is form of haru
# 1

# %%
name = "Lokesh"
friend = "choudry"

mango = """ Mango is sweet fruit
it has lots of variety"""
print(type(mango))
print(name,"is friend of ", friend, "and he likes",mango)
# Out:
# <class 'str'>
# Lokesh is friend of  choudry and he likes  Mango is sweet fruit
# it has lots of variety
